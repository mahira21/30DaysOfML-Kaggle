# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# ## Line charts with Spotify dataset

# %%
# save filepath to variable for easier access
spotify_filepath ="Visualization_data/spotify.csv"
# read the data and store data in DataFrame titled melbourne_data
spotify_data = pd.read_csv(spotify_filepath) 
# Print the first 5 rows of the data
spotify_data.head()
# Out:
#          Date  Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# 0  2017-01-06      12287078        NaN                       NaN      NaN
# 1  2017-01-07      13190270        NaN                       NaN      NaN
# 2  2017-01-08      13099919        NaN                       NaN      NaN
# 3  2017-01-09      14506351        NaN                       NaN      NaN
# 4  2017-01-10      14275628        NaN                       NaN      NaN
#
#    Unforgettable
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
# Print the last five rows of the data
spotify_data.tail()
# Out:
#            Date  Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# 361  2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 362  2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 363  2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 364  2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 365  2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#      Unforgettable
# 361      2869783.0
# 362      2743748.0
# 363      2441045.0
# 364      2622693.0
# 365      2627334.0

# %%
# Line chart showing daily global streams of each song 
sns.lineplot(data=spotify_data)
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: >

# %%
# Set the width and height of the figure
plt.figure(figsize=(14,6))

# Add title
plt.title("Daily Global Streams of Popular Songs in 2017-2018")

# Line chart showing daily global streams of each song 
sns.lineplot(data=spotify_data)
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: title={'center': 'Daily Global Streams of Popular Songs in 2017-2018'}>

# %%
list(spotify_data.columns)
# Out:
# ['Date',
#  'Shape of You',
#  'Despacito',
#  'Something Just Like This',
#  'HUMBLE.',
#  'Unforgettable']

# %%
# Set the width and height of the figure
plt.figure(figsize=(14,6))

# Add title
plt.title("Daily Global Streams of Popular Songs in 2017-2018")

# Line chart showing daily global streams of 'Shape of You'
sns.lineplot(data=spotify_data['Shape of You'], label="Shape of You")

# Line chart showing daily global streams of 'Despacito'
sns.lineplot(data=spotify_data['Despacito'], label="Despacito")

# Add label for horizontal axis
plt.xlabel("Date")
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# ## Bar charts and Heatmaps with ign score and flight delays data

# %%
# Path of the file to read
ign_filepath = "Visualization_data/ign_scores.csv"

# Read the file into a variable ign_data
ign_data = pd.read_csv(ign_filepath, index_col="Platform")

# Print the data
ign_data
# Out:
#                         Action  Action, Adventure  Adventure  Fighting  \
# Platform
# Dreamcast             6.882857           7.511111   6.281818  8.200000
# Game Boy Advance      6.373077           7.507692   6.057143  6.226316
# Game Boy Color        6.272727           8.166667   5.307692  4.500000
# GameCube              6.532584           7.608333   6.753846  7.422222
# Nintendo 3DS          6.670833           7.481818   7.414286  6.614286
# Nintendo 64           6.649057           8.250000   7.000000  5.681250
# Nintendo DS           5.903608           7.240000   6.259804  6.320000
# Nintendo DSi          6.827027           8.500000   6.090909  7.500000
# PC                    6.805791           7.334746   7.136798  7.166667
# PlayStation           6.016406           7.933333   6.313725  6.553731
# PlayStation 2         6.467361           7.250000   6.315152  7.306349
# PlayStation 3         6.853819           7.306154   6.820988  7.710938
# ...

# %%
# What is the highest average score received by PC games,for any genre?
high_score = 7.759930

# On the Playstation Vita platform, which genre has the lowest average score? Please provide the name of the column, and put your answer 
# in single quotes (e.g., 'Action', 'Adventure', 'Fighting', etc.)
worst_genre = 'Simulation'

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("Average Score for Racing Games, by Platform")

# Bar chart showing average score for racing games by platform
sns.barplot(x=ign_data['Racing'], y=ign_data.index) # Your code here

# Add label for vertical axis
plt.ylabel("")
# Out:
# Text(0, 0.5, '')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Heatmap showing average game score by platform and genre
# Set the width and height of the figure
plt.figure(figsize=(10,10))

# Add title
plt.title("Average score for racing game, by genre and platform")

# Heatmap showing average arrival delay for each airline by month
sns.heatmap(data=ign_data, annot=True )

# Add label for horizontal axis
plt.xlabel("Genre")
# Out:
# Text(0.5, 80.7222222222222, 'Genre')

# %%
# Path of the file to read
flight_filepath = "Visualization_data/flight_delays.csv"

# Read the file into a variable flight_data
flight_data = pd.read_csv(flight_filepath, index_col="Month")

# Print the data
flight_data
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
# 6      8.191017 -0.220621   5.047155  4.419594  13.952793  19.712951
# 7      3.870440  0.377408   5.841454  1.204862   6.926421  14.464543
# 8      3.193907  2.503899   9.280950  0.653114   5.154422   9.175737
# 9     -1.432732 -1.813800   3.539154 -3.703377   0.851062   0.978460
# 10    -0.580930 -2.993617   3.676787 -5.011516   2.303760   0.082127
# 11     0.772630 -1.916516   1.418299 -3.175414   4.415930  11.164527
# 12     4.149684 -1.846681  13.839290  2.504595   6.685176   9.346221
#
# ...

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("Average Arrival Delay for Spirit Airlines Flights, by Month")

# Bar chart showing average arrival delay for Spirit Airlines flights by month
sns.barplot(x=flight_data.index, y=flight_data['NK'])

# Add label for vertical axis
plt.ylabel("Arrival delay (in minutes)")
# Out:
# Text(0, 0.5, 'Arrival delay (in minutes)')

# %%
# Bar chart showing average arrival delay for Spirit Airlines flights by month
sns.barplot(x=flight_data.index, y=flight_data['NK'])
# Out:
# <Axes: xlabel='Month', ylabel='NK'>

# %%
# Set the width and height of the figure
plt.figure(figsize=(14,7))

# Add title
plt.title("Average Arrival Delay for Each Airline, by Month")

# Heatmap showing average arrival delay for each airline by month
sns.heatmap(data=flight_data, annot=True)

# Add label for horizontal axis
plt.xlabel("Airline")
# Out:
# Text(0.5, 47.7222222222222, 'Airline')

# %%
# Heatmap showing average arrival delay for each airline by month
sns.heatmap(data=flight_data, annot=True)
# Out:
# <Axes: ylabel='Month'>

# %% [markdown]
# ## Scatterplots with candy dataset

# %%
# Path of the file to read
candy_filepath = "Visualization_data/candy.csv"

# Read the file into a variable 
candy_data = pd.read_csv(candy_filepath, index_col="id")

# %%
candy_data.head()
# Out:
#    competitorname chocolate fruity caramel peanutyalmondy nougat  \
# id
# 0       100 Grand       Yes     No     Yes             No     No
# 1    3 Musketeers       Yes     No      No             No    Yes
# 2       Air Heads        No    Yes      No             No     No
# 3      Almond Joy       Yes     No      No            Yes     No
# 4       Baby Ruth       Yes     No     Yes            Yes    Yes
#
#    crispedricewafer hard  bar pluribus  sugarpercent  pricepercent  winpercent
# id
# 0               Yes   No  Yes       No         0.732         0.860   66.971725
# 1                No   No  Yes       No         0.604         0.511   67.602936
# 2                No   No   No       No         0.906         0.511   52.341465
# 3                No   No  Yes       No         0.465         0.767   50.347546
# 4                No   No  Yes       No         0.604         0.767   56.914547

# %%
# Which candy was more popular with survey respondents:'3 Musketeers' or 'Almond Joy'?  (Please enclose your answer in single quotes.)
more_popular = '3 Musketeers'
#Which candy has higher sugar content: 'Air Heads'or 'Baby Ruth'? (Please enclose your answer in single quotes.)
more_sugar = 'Air Heads'

# %%
# Scatter plot showing the relationship between 'sugarpercent' and 'winpercent'
sns.scatterplot(x=candy_data['sugarpercent'], y=candy_data['winpercent'])
# Out:
# <Axes: xlabel='sugarpercent', ylabel='winpercent'>

# %%
# Scatter plot w/ regression line showing the relationship between 'sugarpercent' and 'winpercent'
sns.regplot(x=candy_data['sugarpercent'], y=candy_data['winpercent'])
# Out:
# <Axes: xlabel='sugarpercent', ylabel='winpercent'>

# %%
# Scatter plot showing the relationship between 'pricepercent', 'winpercent', and 'chocolate'
sns.scatterplot(x=candy_data['pricepercent'], y=candy_data['winpercent'], hue=candy_data['chocolate'])
# Out:
# <Axes: xlabel='pricepercent', ylabel='winpercent'>

# %%
# Scatter plot w/ regression line showing with two regression lines, corresponding to (1) chocolate candies and (2) candies without chocolate.
sns.lmplot(x="pricepercent", y="winpercent", hue="chocolate", data=candy_data)

# %%
# Scatter plot showing the relationship between 'chocolate' and 'winpercent'. Put 'chocolate' on the (horizontal) x-axis, and 'winpercent' on the (vertical) y-axis.
sns.swarmplot(x=candy_data['chocolate'], y=candy_data['winpercent'])
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='chocolate', ylabel='winpercent'>

# %% [markdown]
# ## Histograms and density plots with cancer data

# %%
# Path of the files to read
cancer_filepath = "Visualization_data/cancer.csv"

# Fill in the line below to read the file into a variable cancer_data
cancer_data = pd.read_csv(cancer_filepath, index_col="Id")
cancer_data.head()
# Out:
#          Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# Id
# 8510426          B         13.540           14.36             87.46
# 8510653          B         13.080           15.71             85.63
# 8510824          B          9.504           12.44             60.34
# 854941           B         13.030           18.42             82.61
# 85713702         B          8.196           16.84             51.71
#
#           Area (mean)  Smoothness (mean)  Compactness (mean)  \
# Id
# 8510426         566.3            0.09779             0.08129
# 8510653         520.0            0.10750             0.12700
# 8510824         273.9            0.10240             0.06492
# 854941          523.8            0.08983             0.03766
# 85713702        201.9            0.08600             0.05943
#
#           Concavity (mean)  Concave points (mean)  Symmetry (mean)  ...  \
# Id                                                                  ...
# ...

# %%
# In the first five rows of the data, what is the largest value for 'Perimeter (mean)'?
max_perim = 87.46

# What is the value for 'Radius (mean)' for the tumor with Id 8510824?
mean_radius = 9.504

# %%
# Histograms for benign and maligant tumors
sns.histplot(data=cancer_data, x='Area (mean)', hue='Diagnosis')
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Area (mean)', ylabel='Count'>

# %%
# Change the style of the figure - Try out seaborn styles
sns.set_style("darkgrid")
# KDE plots for benign and malignant tumors

sns.kdeplot(data=cancer_data, x='Radius (worst)', hue='Diagnosis', shade=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_14816\3656264889.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=cancer_data, x='Radius (worst)', hue='Diagnosis', shade=True)
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Radius (worst)', ylabel='Density'>
